# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/602.4.8 (KHTML, like Gecko) Version/10.0.3 Safari/602.4.8'})

# %%
from bs4 import BeautifulSoup
import requests

# %%
###London listings
##https://www.airbnb.com/s/London--United-Kingdom/homes?tab_id=all_tab&refinement_paths%5B%5D=%2Fhomes&query=London%2C%20United%20Kingdom&place_id=ChIJdd4hrwug2EcRmSrV3Vo6llI&checkin=2020-07-14&checkout=2020-07-17&children=0&adults=2&source=structured_search_input_header&search_type=search_query

# %%
url='https://www.airbnb.com/s/London--United-Kingdom/homes?tab_id=all_tab&refinement_paths%5B%5D=%2Fhomes&query=London%2C%20United%20Kingdom&place_id=ChIJdd4hrwug2EcRmSrV3Vo6llI&checkin=2020-07-14&checkout=2020-07-17&children=0&adults=2&source=structured_search_input_header&search_type=search_query'

# %%
response=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(response.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for item in soup.select('[itemprop=itemListElement]'):
	try:
		print('----------------------------------------')
		print(item)
		print('----------------------------------------')
	except Exception as e:
		#raise e
		print('')
# Out:
# ----------------------------------------
# ...

# %%
for item in soup.select('[itemprop=itemListElement]'):
	try:
		print('----------------------------------------')
		print(item.select('a')[0]['aria-label'])
		#name = item.find("meta",  itemprop="name")
		print(name)
		print('----------------------------------------')
	except Exception as e:
		#raise e
		print('')
# Out:
# ----------------------------------------
# Charming Flat in Excellent Location.
#
# ----------------------------------------
# Bright and Airy Restyled Victorian Home
#
# ----------------------------------------
# Bijoux yet  luxurious -Belgravia, London
#
# ----------------------------------------
# Excellent Flat in West Kensington
#
# ----------------------------------------
# Lovely Studio In The Heart Of Soho
#
# ----------------------------------------
# Cute Period Flat Immaculate in Heart of Dalston
#
# ----------------------------------------
# Entire Flat w/ Rooftop Penthouse, St John's Wood
#
# ----------------------------------------
# Spacious and modern studio apartment
#
# ----------------------------------------
# Comfortable Room in King's Cross Zone 1 Eurostar
#
# ----------------------------------------
# ⭐️Brilliant Room in Central London⭐️
#
# ----------------------------------------
# ⚡️Shiny double room close to central London ⚡️
#
# ...

# %%
for item in soup.select('[itemprop=itemListElement]'):
	try:
		print('----------------------------------------')
		print(item.select('a')[0]['aria-label'])
		print(item.select('a')[0]['href'])
		print(item.select('._krjbj')[0].get_text())
		print(item.select('._krjbj')[1].get_text())
		print(item.select('._16shi2n')[0].get_text())
		print(item.select('._zkkcbwd')[0].get_text())
		print(name)
		print('----------------------------------------')
	except Exception as e:
		#raise e
		print('')
# Out:
# ----------------------------------------
# Charming Flat in Excellent Location.
# /rooms/49005167?adults=2&previous_page_section_name=1000&federated_search_id=367142bb-d2a2-4fbe-8512-defdf7de9867
# $48 per night
#
# ----------------------------------------
# Bright and Airy Restyled Victorian Home
# /rooms/48994395?adults=2&previous_page_section_name=1000&federated_search_id=367142bb-d2a2-4fbe-8512-defdf7de9867
# $94 per night
#
# ----------------------------------------
# Bijoux yet  luxurious -Belgravia, London
# /rooms/48028470?adults=2&previous_page_section_name=1000&federated_search_id=367142bb-d2a2-4fbe-8512-defdf7de9867
# $71 per night
#
# ----------------------------------------
# Excellent Flat in West Kensington
# /rooms/48820777?adults=2&previous_page_section_name=1000&federated_search_id=367142bb-d2a2-4fbe-8512-defdf7de9867
# $61 per night
#
# ----------------------------------------
# Lovely Studio In The Heart Of Soho
# ...
