# %% [markdown]
# IPO

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from pandas import DataFrame

# %%
a=requests.get("https://www.iposcoop.com/last-100-ipos/").text
soup=bs(a,'lxml')

# %%
#df_list = pd.read_html(a)

# %%
df_list=pd.read_html(a)

# %%
df_list
# Out:
# [                           Company Symbol  ...   Return SCOOP Rating
#  0          Akoya Biosciences, Inc.   AKYA  ...   30.25%          S/O
#  1                    Biomea Fusion   BMEA  ...    9.41%          S/O
#  2        Recursion Pharmaceuticals   RXRX  ...   73.89%          S/O
#  3              agilon health, inc.    AGL  ...   30.43%          S/O
#  4       Esports Technologies, Inc.   EBET  ...  322.50%          S/O
#  ..                             ...    ...  ...      ...          ...
#  95  Fifth Wall Acquisition Corp. I   FWAA  ...    2.90%          S/O
#  96     Immunocore Holdings Limited   IMCR  ...   47.12%          S/O
#  97             Lucira Health, Inc.   LHDX  ...  -53.88%          S/O
#  98                  Pharvaris B.V.   PHVS  ...   39.60%          S/O
#  99     Terns Pharmaceuticals, Inc.   TERN  ...    5.35%          S/O
#
#  [100 rows x 10 columns]]

# %%
#st = {0:'IPO'}

# %%
#stock_exchanges = list()
#for st_e in df_list:
  #stock_exchanges.append(st_e)

# %%
stock_exchanges=list()
for st_e in df_list:
  stock_exchanges.append(st_e)

# %%
ipos=stock_exchanges[0]

# %%
#ipos=stock_exchanges[0]
#ipos
# Out:
#                            Company Symbol  ...   Return SCOOP Rating
# 0          Akoya Biosciences, Inc.   AKYA  ...   30.25%          S/O
# 1                    Biomea Fusion   BMEA  ...    9.41%          S/O
# 2        Recursion Pharmaceuticals   RXRX  ...   73.89%          S/O
# 3              agilon health, inc.    AGL  ...   30.43%          S/O
# 4       Esports Technologies, Inc.   EBET  ...  322.50%          S/O
# ..                             ...    ...  ...      ...          ...
# 95  Fifth Wall Acquisition Corp. I   FWAA  ...    2.90%          S/O
# 96     Immunocore Holdings Limited   IMCR  ...   47.12%          S/O
# 97             Lucira Health, Inc.   LHDX  ...  -53.88%          S/O
# 98                  Pharvaris B.V.   PHVS  ...   39.60%          S/O
# 99     Terns Pharmaceuticals, Inc.   TERN  ...    5.35%          S/O
#
# [100 rows x 10 columns]

# %%
print(ipos.columns)
# Out:
# Index(['Company', 'Symbol', 'Industry', 'Offer Date', 'Shares (millions)',
#        'Offer Price', '1st Day Close', 'Current Price', 'Return',
#        'SCOOP Rating'],
#       dtype='object')

# %%
#print(ipos.columns)
# Out:
# Index(['Company', 'Symbol', 'Industry', 'Offer Date', 'Shares (millions)',
#        'Offer Price', '1st Day Close', 'Current Price', 'Return',
#        'SCOOP Rating'],
#       dtype='object')

# %%
ipox = ipos.rename({'Offer Date': 'OfferDate',
                    'Shares (millions)':'Shares',
                    'Offer Price':'OfferPrice',
                    '1st Day Close':'Day1Close',
                    'Current Price':'CurrentPrice',
                    'SCOOP Rating':'SCOOP'}, axis=1) ##original name: new name

# %%
ipox.head()
# Out:
#                       Company Symbol  ...   Return SCOOP
# 0     Akoya Biosciences, Inc.   AKYA  ...   30.25%   S/O
# 1               Biomea Fusion   BMEA  ...    9.41%   S/O
# 2   Recursion Pharmaceuticals   RXRX  ...   73.89%   S/O
# 3         agilon health, inc.    AGL  ...   30.43%   S/O
# 4  Esports Technologies, Inc.   EBET  ...  322.50%   S/O
#
# [5 rows x 10 columns]

# %%
print(ipox.dtypes)
# Out:
# Company          object
# Symbol           object
# Industry         object
# OfferDate        object
# Shares          float64
# OfferPrice       object
# Day1Close        object
# CurrentPrice     object
# Return           object
# SCOOP            object
# dtype: object

# %%
#ipox.OfferPrice = [x.strip('$') for x in ipox.OfferPrice]
#ipox.CurrentPrice = [x.strip('$') for x in ipox.CurrentPrice]
#ipox.Day1Close = [x.strip('$') for x in ipox.Day1Close]
#ipox.Return = [x.strip('%') for x in ipox.Return]
#print (ipox.dtypes)

# %%
ipox.OfferPrice=[x.strip('$') for x in ipox.OfferPrice]
ipox.CurrentPrice = [x.strip('$') for x in ipox.CurrentPrice]
ipox.Day1Close = [x.strip('$') for x in ipox.Day1Close]
ipox.Return = [x.strip('%') for x in ipox.Return]

# %%
ipox.head()
# Out:
#                       Company Symbol  ...  Return SCOOP
# 0     Akoya Biosciences, Inc.   AKYA  ...   30.25   S/O
# 1               Biomea Fusion   BMEA  ...    9.41   S/O
# 2   Recursion Pharmaceuticals   RXRX  ...   73.89   S/O
# 3         agilon health, inc.    AGL  ...   30.43   S/O
# 4  Esports Technologies, Inc.   EBET  ...  322.50   S/O
#
# [5 rows x 10 columns]

# %%
print (ipox.dtypes)
# Out:
# Company          object
# Symbol           object
# Industry         object
# OfferDate        object
# Shares          float64
# OfferPrice       object
# Day1Close        object
# CurrentPrice     object
# Return           object
# SCOOP            object
# dtype: object

# %%
ipox['OfferPrice'] = ipox['OfferPrice'].astype(float)
ipox['Day1Close'] = ipox['Day1Close'].astype(float)
ipox['CurrentPrice'] = ipox['CurrentPrice'].astype(float)
ipox['Return'] = ipox['Return'].astype(float)

# show the datatypes
print (ipox.dtypes)
# Out:
# Company          object
# Symbol           object
# Industry         object
# OfferDate        object
# Shares          float64
# OfferPrice      float64
# Day1Close       float64
# CurrentPrice    float64
# Return          float64
# SCOOP            object
# dtype: object

# %%
ipox['OfferPrice']=ipox['OfferPrice'].astype(float)

# %%
print (ipox.dtypes)
# Out:
# Company          object
# Symbol           object
# Industry         object
# OfferDate        object
# Shares          float64
# OfferPrice      float64
# Day1Close        object
# CurrentPrice     object
# Return           object
# SCOOP            object
# dtype: object

# %%
ipox.describe()
# Out:
#            Shares  OfferPrice  Day1Close  CurrentPrice       Return
# count  100.000000  100.000000  100.00000    100.000000   100.000000
# mean    19.920000   20.163000   23.90380     22.291700    19.836600
# std     26.902976   37.506304   33.64709     34.814837   110.340333
# min      1.100000    4.000000    0.00000      3.060000   -56.800000
# 25%      6.575000   10.000000   10.01500     10.090000    -5.172500
# 50%     11.400000   16.000000   18.21000     15.570000     2.250000
# 75%     24.400000   20.000000   30.22000     25.510000    17.877500
# max    198.900000  381.000000  328.28000    342.000000  1029.750000
