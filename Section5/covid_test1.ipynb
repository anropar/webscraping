# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import re

# %%
##https://covid19.ncdc.gov.ng/

# %%
url='https://covid19.ncdc.gov.ng/'

# %%
#r = requests.get(url)
#df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list

# %%
r=requests.get(url)

# %%
df_lists=pd.read_html(r.text)

# %%
len(df_lists)
# Out:
# 1

# %%
ccase = list() ##cacase is empty
for st_e in df_list:
  ccase.append(st_e) ##append the table to the empty list

# %%
ccase[0] ##first table
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  ...  No. Discharged  No. of Deaths
# 0            Lagos                         57822  ...           56990            439
# 1              FCT                         19678  ...           18073            164
# 2          Plateau                          9028  ...            8949             57
# 3           Kaduna                          8967  ...            8855             65
# 4           Rivers                          6948  ...            6829            100
# 5              Oyo                          6838  ...            6241            123
# 6              Edo                          4886  ...            4696            185
# 7             Ogun                          4620  ...            4562             49
# 8             Kano                          3913  ...            3777            110
# 9             Ondo                          3220  ...            2080             63
# 10           Kwara                          3120  ...            2814             55
# 11           Delta                          2608  ...            1744             71
# 12            Osun                          2541  ...            2457             52
# 13        Nasarawa                          2364  ...             373             13
# 14           Enugu                          2255  ...            1973             29
# 15         Katsina                          2097  ...            2049             34
# 16           Gombe                          2033  ...            1984             44
# 17          Ebonyi                          2007  ...            1951             32
# 18         Anambra                          1909  ...            1826             19
# 19       Akwa Ibom                          1780  ...            1603             14
# 20            Abia                          1676  ...            1645             21
# 21             Imo                          1655  ...            1592             37
# 22          Bauchi                          1531  ...            1501             17
# 23           Borno                          1337  ...            1200             38
# 24           Benue                          1188  ...             591             22
# 25         Adamawa                          1051  ...             274             32
# 26           Niger                           930  ...             417             17
# 27          Taraba                           910  ...             864             22
# 28           Ekiti                           867  ...             837             11
# 29         Bayelsa                           861  ...             819             26
# 30          Sokoto                           774  ...             746             28
# 31          Jigawa                           524  ...             485             16
# 32           Kebbi                           450  ...             392             16
# 33     Cross River                           377  ...             348             18
# 34            Yobe                           328  ...             284              9
# 35         Zamfara                           232  ...             221              8
# 36            Kogi                             5  ...               3              2
#
# [37 rows x 5 columns]
