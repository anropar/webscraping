# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd

# %%
url='/content/drive/MyDrive/Python_text/Data_Code/section7/MumbaiGeoMerge.csv'

# %%
mumbai=pd.read_csv(url)

# %%
mumbai.head()
# Out:
#    Unnamed: 0            Area  ...   latitude  longitude
# 0          41          Amboli  ...  19.136394  72.837382
# 1          69      D.N. Nagar  ...  19.117249  72.833968
# 2         126  Four Bungalows  ...  19.117249  72.833968
# 3         212     Lokhandwala  ...  19.136394  72.837382
# 4         514       Bhayandar  ...  19.281697  72.856068
#
# [5 rows x 14 columns]

# %% [markdown]
# Categorization

# %%
mumbai['Trend'] = pd.cut(x=mumbai['Change'], bins=[20, 29, 39, 49], labels=['20s', '30s', '40s'])

# %%
mumbai
# Out:
#     Unnamed: 0                 Area  ...                  quantile_ex_1  Trend
# 0           41               Amboli  ...                 (15.75, 37.45]    30s
# 1           69           D.N. Nagar  ...                  (37.45, 62.9]    40s
# 2          126       Four Bungalows  ...                  (37.45, 62.9]    40s
# 3          212          Lokhandwala  ...                 (15.75, 37.45]    30s
# 4          514            Bhayandar  ...                (-9.625, 15.75]    NaN
# 5          701             Kherwadi  ...  (-19.801000000000002, -9.625]    NaN
# 6          758            Pali Hill  ...  (-19.801000000000002, -9.625]    NaN
# 7          816          I.C. Colony  ...                  (37.45, 62.9]    NaN
# 8          994         Bangur Nagar  ...                (-9.625, 15.75]    NaN
# 9         1105               Poisar  ...                 (15.75, 37.45]    30s
# 10        1162        Mahavir Nagar  ...                 (15.75, 37.45]    30s
# ...
